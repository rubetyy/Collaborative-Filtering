# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
review_data = pd.read_csv('최종review.csv',encoding='cp949')

# %%
tour_data1 = pd.read_csv('최종tour.csv',encoding='cp949')
# Out:
# c:\users\night\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3427: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
tour_data2 = pd.read_csv('최종전처리_광훈.csv')

# %%
type_data = pd.read_csv('최종분류.csv')

# %%
review_data
# Out:
#         Spot_pk ItemID   UserID  Rating  \
# 0             1  호국전진사  15lk2ck       4
# 1             3   용마루길   g6kl0d       5
# 2             3   용마루길   e9e5k4       3
# 3             6    불승사  11c27np       5
# 4            10    태현사   ma79f8       5
# ...         ...    ...      ...     ...
# 155971    62512  게으른악어   uh3jcv       4
# 155972    62512  게으른악어   vb1990       4
# 155973    62512  게으른악어   n51lqr       3
# 155974    62512  게으른악어  18hc6db       5
# 155975    62512  게으른악어   g9bmec       4
#
#                                                    review    Timestamp
# 0                                                     NaN  2020.01.21.
# 1                                                     NaN  2021.08.10.
# 2                                                     NaN  2019.02.22.
# 3                                                     NaN  2021.04.16.
# 4                           조용하고 잔잔해서 강아지 산책할 때마다 종종 들립니다  2021.05.16.
# ...

# %%
tour_data1
# Out:
#                      id lclas mlsfc    id_poi          poi_nm branch_nm  \
# 0      KC495PP19N000001    장소   관광지  10000098           호국전진사       NaN
# 1      KC495PP19N000002    장소   관광지  10000162         상주옹기판매장       NaN
# 2      KC495PP19N000003    장소   관광지  10000211          추월산관광지       NaN
# 3      KC495PP19N000004    장소   관광지  10000381            쇄기농장       NaN
# 4      KC495PP19N000005    장소   관광지  10206030             보타사       NaN
# ...                 ...   ...   ...       ...             ...       ...
# 37208  KC495PP19N037209    장소   관광지  17507693     안성팜랜드초원눈썰매장       NaN
# 37209  KC495PP19N037210    장소   관광지  21050671      내장산단풍겨울빛축제       NaN
# 37210  KC495PP19N037211    장소   관광지  20935225          오대산선재길       NaN
# 37211  KC495PP19N037212    장소   관광지  21085804    덕유산국립공원시인의거리       NaN
# 37212  KC495PP19N037213    장소   관광지  20942153  의왕자연학습공원의왕레일파크       NaN
#
#        sub_nm  mcate_cd      mcate_nm           pnu  ...           x  \
# ...

# %%
tour_data1_ch = pd.DataFrame()

# %%
tour_data1_ch['Spot_pk'] = tour_data1['Spot_pk']
tour_data1_ch['contenttypeid'] = tour_data1['mlsfc']
tour_data1_ch['cat3'] = tour_data1['mcate_nm']
tour_data1_ch['title'] = tour_data1['poi_nm']
tour_data1_ch['code'] = tour_data1['code']

# %%
tour_data1_ch
# Out:
#        Spot_pk contenttypeid          cat3           title   code
# 0            1           관광지          지역사찰           호국전진사  31200
# 1            2           관광지  토속/특산물/기념품매장         상주옹기판매장  37080
# 2            3           관광지         일반관광지          추월산관광지  36310
# 3            4           관광지  토속/특산물/기념품매장            쇄기농장  39020
# 4            5           관광지          지역사찰             보타사  32010
# ...        ...           ...           ...             ...    ...
# 37208    37209           관광지          지역축제     안성팜랜드초원눈썰매장  31220
# 37209    37210           관광지          지역축제      내장산단풍겨울빛축제  35360
# 37210    37211           관광지         일반관광지          오대산선재길  32340
# 37211    37212           관광지      먹거리/패션거리    덕유산국립공원시인의거리  35330
# 37212    37213           관광지   테마공원/대형놀이공원  의왕자연학습공원의왕레일파크  31170
#
# [37213 rows x 5 columns]

# %%
# tour_data1_ch['cat3'] == '관광지' # 12로
# # 문화 -14 , 축제/공연/행사- 15 ,

# %%
tour_data1_ch.loc[tour_data1_ch['cat3'] == '관광농원/허브마을', 'cat3'] = '관광농원'
tour_data1_ch.loc[tour_data1_ch['cat3'] == '대형호수/저수지', 'cat3'] = '호수'
tour_data1_ch.loc[tour_data1_ch['cat3'] == '동물원', 'cat3'] = '유원지'
tour_data1_ch.loc[tour_data1_ch['cat3'] == '먹거리/패션거리', 'cat3'] = '기타행사'
tour_data1_ch.loc[tour_data1_ch['cat3'] == '서원/향교/서당', 'cat3'] = '전통체험'
tour_data1_ch.loc[tour_data1_ch['cat3'] == '세븐럭카지노', 'cat3'] = '카지노'
tour_data1_ch.loc[tour_data1_ch['cat3'] == '숲', 'cat3'] = '자연휴양림'
# tour_data1_ch.loc[tour_data1_ch['cat3'] == '아쿠아리움/대형수족관', 'cat3'] = '???
# tour_data1_ch.loc[tour_data1_ch['cat3'] == '유명관광지', 'cat3'] = '???
tour_data1_ch.loc[tour_data1_ch['cat3'] == '유명사찰', 'cat3'] = '사찰'
# tour_data1_ch.loc[tour_data1_ch['cat3'] == '일반관광지', 'cat3'] = '???'
tour_data1_ch.loc[tour_data1_ch['cat3'] == '일반유원지/일반놀이공원', 'cat3'] = '유원지'
tour_data1_ch.loc[tour_data1_ch['cat3'] == '지역사찰', 'cat3'] = '사찰'
tour_data1_ch.loc[tour_data1_ch['cat3'] == '지역축제', 'cat3'] = '문화관광축제'
tour_data1_ch.loc[tour_data1_ch['cat3'] == '지역호수/저수지', 'cat3'] = '호수'
tour_data1_ch.loc[tour_data1_ch['cat3'] == '테마공원/대형놀이공원', 'cat3'] = '유원지'
tour_data1_ch.loc[tour_data1_ch['cat3'] == '토속/특산물/기념품매장', 'cat3'] = '특산물판매점'
tour_data1_ch.loc[tour_data1_ch['cat3'] == '파라다이스카지노', 'cat3'] = '카지노'
tour_data1_ch.loc[tour_data1_ch['cat3'] == '폭포/계곡', 'cat3'] = '계곡'
tour_data1_ch.loc[tour_data1_ch['cat3'] == '휴양림/수목원', 'cat3'] = '자연휴양림'

# %%
# tour_data1_ch[(tour_data1_ch['cat3'] == '관광농원/허브마을')] = '관광농원'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '대형호수/저수지')] = '호수'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '동물원')] = '유원지'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '먹거리/패션거리')] = '기타행사'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '서원/향교/서당')] = '전통체험'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '세븐럭카지노')] = '카지노'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '숲')] = '자연휴양림'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '식물원')] = '수목원'   
# # tour_data1_ch[(tour_data1_ch['cat3'] == '아쿠아리움/대형수족관')] = '???'   
# # tour_data1_ch[(tour_data1_ch['cat3'] == '유명관광지')] = '???'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '유명사찰')] = '사찰'   
# # tour_data1_ch[(tour_data1_ch['cat3'] == '일반관광지')] = '???'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '일반유원지/일반놀이공원')] = '유원지'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '지역사찰')] = '사찰'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '지역축제')] = '문화관광축제'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '지역호수/저수지')] = '호수'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '테마공원/대형놀이공원')] = '유원지'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '토속/특산물/기념품매장')] = '특산물판매점'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '파라다이스카지노')] = '카지노'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '폭포/계곡')] = '계곡'   
# tour_data1_ch[(tour_data1_ch['cat3'] == '휴양림/수목원')] = '자연휴양림'

# %%
tour_data1_ch
# Out:
#        Spot_pk contenttypeid          cat3           title   code
# 0            1           관광지          지역사찰           호국전진사  31200
# 1            2           관광지  토속/특산물/기념품매장         상주옹기판매장  37080
# 2            3           관광지         일반관광지          추월산관광지  36310
# 3            4           관광지  토속/특산물/기념품매장            쇄기농장  39020
# 4            5           관광지          지역사찰             보타사  32010
# ...        ...           ...           ...             ...    ...
# 37208    37209           관광지          지역축제     안성팜랜드초원눈썰매장  31220
# 37209    37210           관광지          지역축제      내장산단풍겨울빛축제  35360
# 37210    37211           관광지         일반관광지          오대산선재길  32340
# 37211    37212           관광지      먹거리/패션거리    덕유산국립공원시인의거리  35330
# 37212    37213           관광지   테마공원/대형놀이공원  의왕자연학습공원의왕레일파크  31170
#
# [37213 rows x 5 columns]

# %%
tour_data2
# Out:
#        areacode cat1   cat2       cat3  contentid  contenttypeid        mapx  \
# 0            32  A01  A0101  A01010600     125266             12  128.291911
# 1            35  A01  A0101  A01010600     125405             12  129.365504
# 2             4  A01  A0101  A01010600     125406             12  128.515977
# 3            35  A01  A0101  A01010600     125407             12  128.134266
# 4            35  A01  A0101  A01010600     125408             12  129.053721
# ...         ...  ...    ...        ...        ...            ...         ...
# 25295        33  A05  A0502  A05020100    2741113             39  127.479590
# 25296        39  A05  A0502  A05020900    2741116             39  126.921204
# 25297         1  A02  A0202  A02020700    2741117             12  127.021482
# 25298        33  A05  A0502  A05020900    2741121             39  128.048101
# 25299         1  A02  A0207  A02070200    2741123             15  126.895045
#
# ...

# %%
tour_data2_ch = pd.DataFrame()

# %%
tour_data2_ch['Spot_pk'] = tour_data2['Spot_pk']
tour_data2_ch['contenttypeid'] = tour_data2['contenttypeid']
tour_data2_ch['cat1'] = tour_data2['cat1']
tour_data2_ch['cat2'] = tour_data2['cat2']
tour_data2_ch['cat3'] = tour_data2['cat3']
tour_data2_ch['title'] = tour_data2['title']
tour_data2_ch['code'] = tour_data2['code']

# %%
tour_data2_ch
# Out:
#        Spot_pk  contenttypeid cat1   cat2       cat3  \
# 0        37214             12  A01  A0101  A01010600
# 1        37215             12  A01  A0101  A01010600
# 2        37216             12  A01  A0101  A01010600
# 3        37217             12  A01  A0101  A01010600
# 4        37218             12  A01  A0101  A01010600
# ...        ...            ...  ...    ...        ...
# 25295    62509             39  A05  A0502  A05020100
# 25296    62510             39  A05  A0502  A05020900
# 25297    62511             12  A02  A0202  A02020700
# 25298    62512             39  A05  A0502  A05020900
# 25299    62513             15  A02  A0207  A02070200
#
#                            title   code
# 0                    국립 청태산자연휴양림  32320
# 1                       토함산자연휴양림  37020
# 2                       비슬산자연휴양림  22310
# 3                        불정자연휴양림  37090
# 4      청송 자연휴양림 퇴적암층 (청송 국가지질공원)  37330
# ...                          ...    ...
# ...

# %%
type_data
# Out:
#     contenttypeid cat1   cat2       cat3 대분류    중분류      소분류
# 0             관광지  A01  A0101  A01010100  자연  자연관광지     국립공원
# 1             관광지  A01  A0101  A01010200  자연  자연관광지     도립공원
# 2             관광지  A01  A0101  A01010300  자연  자연관광지     군립공원
# 3             관광지  A01  A0101  A01010400  자연  자연관광지        산
# 4             관광지  A01  A0101  A01010500  자연  자연관광지  자연생태관광지
# ..            ...  ...    ...        ...  ..    ...      ...
# 169            음식  A05  A0502  A05020600  음식    음식점  패밀리레스토랑
# 170            음식  A05  A0502  A05020700  음식    음식점    이색음식점
# 171            음식  A05  A0502  A05020800  음식    음식점    채식전문점
# 172            음식  A05  A0502  A05020900  음식    음식점     바/까페
# 173            음식  A05  A0502  A05021000  음식    음식점       클럽
#
# [174 rows x 7 columns]

# %%
# tour_data1_ch 을  type_data로 cat3에 맞춰 앞에 넣기
